# %% [markdown]
# ---
#
# <!-- <a href="https://github.com/rraadd88/roux/blob/master/examples/roux_viz_line.ipynb"><img align="right" style="float:right;" src="https://img.shields.io/badge/-source-cccccc?style=flat-square"></a>
#  -->
#
# ## 📈 Line plots.

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ### Step plot

# %% [markdown]
# **Demo data**

# %%
import pandas as pd
data=pd.DataFrame({
    'sample size':[100,30,60,50,30,20,25],
    })
data['step name']='step#'+(data.index+1).astype(str)
data
# Out:
#    sample size step name
# 0          100    step#1
# 1           30    step#2
# 2           60    step#3
# 3           50    step#4
# 4           30    step#5
# 5           20    step#6
# 6           25    step#7

# %% [markdown]
# #### Plot

# %%
from roux.viz.line import plot_steps
ax=plot_steps(
    data,
    col_step_name='step name',
    col_step_size='sample size',
    )

# %% [markdown]
# ## bezier lines

# %%
from roux.viz.line import plot_bezier
# %run ../../roux/roux/viz/line.py
fig,ax=plt.subplots(figsize=[2,2])
for direction in ['h','v']:
    for off_guide in [0.25,0.75,1]:
        plot_bezier(
            [0,0],
            [1,1],
            direction=direction,
            off_guide=off_guide,
            test=True,
        )
ax.axis('off')
_=plt.legend(bbox_to_anchor=[1,1],title='guides')

# %% [markdown]
# ### Documentation
# [`roux.viz.line`](https://github.com/rraadd88/roux#module-rouxvizline)
