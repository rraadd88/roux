# %% [markdown]
# ## Examples

# %% [markdown]
# ## Saving plots with the source data

# %%
# demo data
import seaborn as sns
df1=sns.load_dataset('iris')

# %%
# import helper functions
from roux.global_imports import *

## parameters
kws_plot=dict(y='sepal_width')
## log the code from this cell of the notebook
log_code()
# plot
fig,ax=plt.subplots(figsize=[3,3])
sns.scatterplot(data=df1,x='sepal_length',y=kws_plot['y'],hue='species',
                ax=ax,)
## save the plot
to_plot('plot/plot_saved.png',# filename
       df1=df1, #source data
       kws_plot=kws_plot,# plotting parameters
       )
assert exists('plot/plot_saved.png')
# Out:
# /home/rohan/anaconda3/envs/test/lib/python3.7/site-packages/IPython/core/magics/logging.py:130: UserWarning: Couldn't start log: Log file is already active: log_notebook.log
#   warn("Couldn't start log: %s" % sys.exc_info()[1])

# %% [markdown]
# ## "Reading" the plots

# %%
read_plot('plot/plot_saved.png')
# Out:
# WARNING:root:dropped columns: Unnamed: 0
# INFO:root:shape = (150, 5)
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %% [markdown]
# ## "Reading" the plot and modifying its parameters

# %%
read_plot('plot/plot_saved.png',kws_plot=dict(y='petal_length'),title='modified')
# Out:
# WARNING:root:dropped columns: Unnamed: 0
# INFO:root:shape = (150, 5)
# <AxesSubplot:title={'center':'modified'}, xlabel='sepal_length', ylabel='petal_length'>

# %% [markdown]
# ## Documentation
# [`roux.viz.io`](https://github.com/rraadd88/roux/wiki/roux.viz#rouxvizio-module)
