# %% [markdown]
# ---
#
# <!-- <a href="https://github.com/rraadd88/roux/blob/master/examples/roux_viz_theme.ipynb"><img align="right" style="float:right;" src="https://img.shields.io/badge/-source-cccccc?style=flat-square"></a>
#  -->
#
# ## 📈🎨✨ Visualizations theming.

# %% [markdown]
# **Demo data and parameters**

# %%
## required functions
from roux.viz.io import read_plot

# %%
## parameters
### input path
input_path='tests/output/plot/plot_saved.png'

# %% [markdown]
# ## Base theme

# %%
_=read_plot(input_path)
# Out:
# WARNING:root:Optional interactive-use dependencies missing, install by running: pip install roux[interactive]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# WARNING:root:Optional dependency pandarallel missing, install by running: pip install roux[fast]
# INFO:root:shape = (150, 5)

# %% [markdown]
# ## Theming

# %%
from roux.viz.theme import set_theme #noqa

# %%
ax=read_plot(input_path)

from roux.viz.ax_ import format_ax
_=format_ax(ax=ax)

_=ax.legend(bbox_to_anchor=[1,1])
# Out:
# INFO:root:shape = (150, 5)

# %% [markdown]
# #### Documentation
# [`roux.viz.theme`](https://github.com/rraadd88/roux#module-rouxviztheme)
