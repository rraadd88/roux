# %% [markdown]
# ---
#
# <!-- <a href="https://github.com/rraadd88/roux/blob/master/examples/roux_viz_dist.ipynb"><img align="right" style="float:right;" src="https://img.shields.io/badge/-source-cccccc?style=flat-square"></a>
#  -->
#
# ## 📈 Distribution plots.

# %%
# installing the required roux subpackage
# !pip install roux[viz]
# loading requirements
import seaborn as sns
import matplotlib.pyplot as plt
# ## for saving plots
# from roux.viz.io import to_plot

# %% [markdown]
# ### Demo data

# %%
df1=sns.load_dataset('iris')
# df1=df1.loc[df1['species'].isin(['setosa','virginica']),:]
df1['id']=range(len(df1))
df1.head(1)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species  id
# 0           5.1          3.5           1.4          0.2  setosa   0

# %% [markdown]
# ### `showmeans`

# %%
fig,ax=plt.subplots(figsize=[2,2])
from roux.viz.dist import plot_dists
ax=plot_dists(
    df1,x='sepal_length',y='species',colindex='id',
    # showmeans=False,
    order=['setosa','virginica']
)
# to_plot('./outputs/roux_viz_dists/plot_dists_h.png')
# Out:
# /home/rdandage/Documents/work/roux/roux/viz/ax_.py:414: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   _ = getattr(ax, f"set_{k}")(

# %% [markdown]
# ### Paired horizontal (preferred)

# %%
fig,ax=plt.subplots(figsize=[2,2])
from roux.viz.dist import plot_dists
ax=plot_dists(df1,x='sepal_length',y='species',colindex='id',kind=['box','strip'],order=['setosa','virginica'],showmeans=False,)
# to_plot('./outputs/roux_viz_dists/plot_dists_h.png')
# Out:
# /home/rdandage/Documents/work/roux/roux/viz/ax_.py:414: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   _ = getattr(ax, f"set_{k}")(

# %% [markdown]
# ### Paired vertical

# %%
fig,ax=plt.subplots(figsize=[2,2])
from roux.viz.dist import plot_dists
ax=plot_dists(
    df1,
    x='species',
    y='sepal_length',
    colindex='id',
    kind=['box','strip'],
    order=['setosa','virginica'],
    offs_pval=dict(y=0.25),
    showmeans=False,
    )
sns.despine()
# to_plot('./outputs/roux_viz_dists/plot_dists_v.png')
# Out:
# /home/rdandage/Documents/work/roux/roux/viz/ax_.py:414: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   _ = getattr(ax, f"set_{k}")(

# %% [markdown]
# ### >2 categories

# %%
fig,ax=plt.subplots(figsize=[3,2])# larger figure size
from roux.viz.dist import plot_dists
ax=plot_dists(
    df1,
    x='sepal_length',
    y='species',
    colindex='id',
    kind=['box','strip'],
    offs_pval=dict(y=-0.25),
    showmeans=False,
    )
# plt.tight_layout()
# ax.set(
#     xlim=(ax.get_xlim()[0],ax.get_xlim()[1]+1)
# )
# to_plot('./outputs/roux_viz_dists/plot_dists_v_gt2.png')
# Out:
# /home/rdandage/Documents/work/roux/roux/viz/ax_.py:414: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   _ = getattr(ax, f"set_{k}")(

# %%
fig,ax=plt.subplots(figsize=[3,2])# larger figure size
from roux.viz.dist import plot_dists
ax=plot_dists(
    df1,
    x='species',
    y='sepal_length',
    colindex='id',
    kind=['box','strip'],
    offs_pval=dict(y=0.25),
    showmeans=False,    
    )
sns.despine()
# to_plot('./outputs/roux_viz_dists/plot_dists_v_gt2.png')
# Out:
# /home/rdandage/Documents/work/roux/roux/viz/ax_.py:414: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   _ = getattr(ax, f"set_{k}")(

# %% [markdown]
# ## Documentation
# [`roux.viz.dist`](https://github.com/rraadd88/roux#module-rouxvizdist)
